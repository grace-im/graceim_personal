# %% [raw]
# Dataset of vaccination growth

# %%
import requests
covid_cases_url = 'https://idph.illinois.gov/DPHPublicInformation/api/covidVaccine/getVaccineAdministration?countyName=Illinois'

cases_response = requests.get(covid_cases_url)
cases_response.raise_for_status() # raise exception if invalid response
cases_response
# Out:
# <Response [200]>

# %% [raw]
# Vaccination dateset from github.

# %%
import requests
covid_vaccination_url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/us_state_vaccinations.csv'

vaccination_response = requests.get(covid_vaccination_url)
vaccination_response.raise_for_status() # raise exception if invalid response
vaccination_response

# %% [raw]
# Read csv of covid vaccinatio url to create a data set.

# %%
import pandas as pd
vaccination_df = pd.read_csv(covid_vaccination_url)
vaccination_df.head(10)
# Out:
#          date location  total_vaccinations  total_distributed  \
# 0  2021-01-12  Alabama             78134.0           377025.0
# 1  2021-01-13  Alabama             84040.0           378975.0
# 2  2021-01-14  Alabama             92300.0           435350.0
# 3  2021-01-15  Alabama            100567.0           444650.0
# 4  2021-01-16  Alabama                 NaN                NaN
# 5  2021-01-17  Alabama                 NaN                NaN
# 6  2021-01-18  Alabama                 NaN                NaN
# 7  2021-01-19  Alabama            130795.0           444650.0
# 8  2021-01-20  Alabama            139200.0           483275.0
# 9  2021-01-21  Alabama            165919.0           493125.0
#
#    people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0            70861.0                                 0.15
# 1            74792.0                                 0.19
# 2            80480.0                                  NaN
# 3            86956.0                                 0.28
# 4                NaN                                  NaN
# 5                NaN                                  NaN
# 6                NaN                                  NaN
# 7           114319.0                                 0.33
# 8           121113.0                                 0.37
# 9           144429.0                                 0.44
#
#    total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                            1.59                   7270.0
# 1                            1.71                   9245.0
# 2                            1.88                      NaN
# 3                            2.05                  13488.0
# 4                             NaN                      NaN
# 5                             NaN                      NaN
# 6                             NaN                      NaN
# 7                            2.67                  16346.0
# 8                            2.84                  17956.0
# 9                            3.38                  21345.0
#
#    people_vaccinated_per_hundred  distributed_per_hundred  \
# 0                           1.45                     7.69
# 1                           1.53                     7.73
# 2                           1.64                     8.88
# 3                           1.77                     9.07
# 4                            NaN                      NaN
# 5                            NaN                      NaN
# 6                            NaN                      NaN
# 7                           2.33                     9.07
# 8                           2.47                     9.86
# 9                           2.95                    10.06
#
#    daily_vaccinations_raw  daily_vaccinations  daily_vaccinations_per_million  \
# 0                     NaN                 NaN                             NaN
# 1                  5906.0              5906.0                          1205.0
# 2                  8260.0              7083.0                          1445.0
# 3                  8267.0              7478.0                          1525.0
# 4                  7557.0              7498.0                          1529.0
# 5                  7557.0              7509.0                          1531.0
# 6                  7557.0              7517.0                          1533.0
# 7                  7557.0              7523.0                          1534.0
# 8                  8405.0              7880.0                          1607.0
# 9                 26719.0             10517.0                          2145.0
#
#    share_doses_used
# 0             0.207
# 1             0.222
# 2             0.212
# 3             0.226
# 4               NaN
# 5               NaN
# 6               NaN
# 7             0.294
# 8             0.288
# 9             0.336

# %% [raw]
# The dataset above has all states vaccination numbers
# Have to filter out only Illinois vaccination data

# %%
illinois = vaccination_df['location'] == 'Illinois'
illinois_vaccination = vaccination_df[illinois]
illinois_vaccination.head()
# Out:
#             date  location  total_vaccinations  total_distributed  \
# 1080  2021-01-12  Illinois            347005.0           903100.0
# 1081  2021-01-13  Illinois            365859.0           920225.0
# 1082  2021-01-14  Illinois            403666.0           958125.0
# 1083  2021-01-15  Illinois            437765.0          1011225.0
# 1084  2021-01-16  Illinois                 NaN                NaN
#
#       people_vaccinated  people_fully_vaccinated_per_hundred  \
# 1080           284035.0                                 0.50
# 1081           291445.0                                 0.59
# 1082           316876.0                                  NaN
# 1083           341518.0                                 0.72
# 1084                NaN                                  NaN
#
#       total_vaccinations_per_hundred  people_fully_vaccinated  \
# 1080                            2.74                  62757.0
# 1081                            2.89                  74186.0
# 1082                            3.19                      NaN
# 1083                            3.45                  91248.0
# 1084                             NaN                      NaN
#
#       people_vaccinated_per_hundred  distributed_per_hundred  \
# 1080                           2.24                     7.13
# 1081                           2.30                     7.26
# 1082                           2.50                     7.56
# 1083                           2.70                     7.98
# 1084                            NaN                      NaN
#
#       daily_vaccinations_raw  daily_vaccinations  \
# 1080                     NaN                 NaN
# 1081                 18854.0             18854.0
# 1082                 37807.0             28330.0
# 1083                 34099.0             30253.0
# 1084                 21874.0             28158.0
#
#       daily_vaccinations_per_million  share_doses_used
# 1080                             NaN             0.384
# 1081                          1488.0             0.398
# 1082                          2236.0             0.421
# 1083                          2387.0             0.433
# 1084                          2222.0               NaN

# %% [raw]
# Drop unnecessary columns to have a better dataset to understand
# From 1/16/21 to 1/18/21, no total vaccination numbers were given so using dropna() I got rid of NA value

# %%
illinois_drop = illinois_vaccination.drop(columns = ['total_distributed','people_vaccinated','people_fully_vaccinated_per_hundred','total_vaccinations_per_hundred',
                       'people_fully_vaccinated','people_vaccinated_per_hundred','total_vaccinations_per_hundred','people_fully_vaccinated','people_vaccinated_per_hundred',
                                    'people_vaccinated_per_hundred','distributed_per_hundred','daily_vaccinations_raw','daily_vaccinations','daily_vaccinations_per_million','share_doses_used'], axis = 1)
vaccination_final = illinois_drop.dropna()
vaccination_final.head()
# Out:
#             date  location  total_vaccinations
# 1080  2021-01-12  Illinois            347005.0
# 1081  2021-01-13  Illinois            365859.0
# 1082  2021-01-14  Illinois            403666.0
# 1083  2021-01-15  Illinois            437765.0
# 1087  2021-01-19  Illinois            525261.0

# %%
line = vaccination_final.plot.line(x = 'date', y = 'total_vaccinations')
line
# Out:
# <AxesSubplot:xlabel='date'>
